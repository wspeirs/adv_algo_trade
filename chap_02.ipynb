# %% [markdown]
# # 2.3 Coin-Flipping Example

# %%
# !conda install -y scipy
# !conda install -y matplotlib
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/wspeirs/miniconda3
#
#   added / updated specs:
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     scipy-1.13.1               |  py312hc5e2394_0        23.7 MB
#     ------------------------------------------------------------
#                                            Total:        25.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5       pkgs/main/linux-64::libgfortran5-11.2.0-h1234567_1
#   scipy              pkgs/main/linux-64::scipy-1.13.1-py312hc5e2394_0
#
#
#
# Downloading and Extracting Packages:
# scipy-1.13.1         | 23.7 MB   |                                       |   0%
# libgfortran5-11.2.0  | 2.0 MB    |                                       |   0%
#
# libgfortran-ng-11.2. | 20 KB     |                                       |   0%
# scipy-1.13.1         | 23.7 MB   | ######2                               |  17%
# libgfortran5-11.2.0  | 2.0 MB    | ##################################### | 100%
# scipy-1.13.1         | 23.7 MB   | ##################################### | 100%
#
# libgfortran-ng-11.2. | 20 KB     | #############################9        |  81%
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/wspeirs/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h5eee18b_8          18 KB
#     brotli-bin-1.0.9           |       h5eee18b_8          19 KB
#     contourpy-1.2.0            |  py312hdb19cb5_0         238 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     fonttools-4.51.0           |  py312h5eee18b_0         2.9 MB
#     kiwisolver-1.4.4           |  py312h6a678d5_0          68 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     lerc-3.0                   |       h295c915_0         196 KB
#     libbrotlicommon-1.0.9      |       h5eee18b_8          69 KB
#     libbrotlidec-1.0.9         |       h5eee18b_8          31 KB
#     libbrotlienc-1.0.9         |       h5eee18b_8         286 KB
#     libdeflate-1.17            |       h5eee18b_1          64 KB
#     libtiff-4.5.1              |       h6a678d5_0         533 KB
#     libwebp-base-1.3.2         |       h5eee18b_0         387 KB
#     matplotlib-3.8.4           |  py312h06a4308_0           8 KB
#     matplotlib-base-3.8.4      |  py312h526ad5a_0         7.6 MB
#     openjpeg-2.5.2             |       he7f1fd0_0         371 KB
#     pillow-10.4.0              |  py312h5eee18b_0         946 KB
#     pyparsing-3.0.9            |  py312h06a4308_0         197 KB
#     unicodedata2-15.1.0        |  py312h5eee18b_0         519 KB
#     ------------------------------------------------------------
#                                            Total:        14.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/linux-64::brotli-1.0.9-h5eee18b_8
#   brotli-bin         pkgs/main/linux-64::brotli-bin-1.0.9-h5eee18b_8
#   contourpy          pkgs/main/linux-64::contourpy-1.2.0-py312hdb19cb5_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/linux-64::fonttools-4.51.0-py312h5eee18b_0
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.4-py312h6a678d5_0
#   lcms2              pkgs/main/linux-64::lcms2-2.12-h3be6417_0
#   lerc               pkgs/main/linux-64::lerc-3.0-h295c915_0
#   libbrotlicommon    pkgs/main/linux-64::libbrotlicommon-1.0.9-h5eee18b_8
#   libbrotlidec       pkgs/main/linux-64::libbrotlidec-1.0.9-h5eee18b_8
#   libbrotlienc       pkgs/main/linux-64::libbrotlienc-1.0.9-h5eee18b_8
#   libdeflate         pkgs/main/linux-64::libdeflate-1.17-h5eee18b_1
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-h6a678d5_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.3.2-h5eee18b_0
#   matplotlib         pkgs/main/linux-64::matplotlib-3.8.4-py312h06a4308_0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.8.4-py312h526ad5a_0
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   pillow             pkgs/main/linux-64::pillow-10.4.0-py312h5eee18b_0
#   pyparsing          pkgs/main/linux-64::pyparsing-3.0.9-py312h06a4308_0
#   unicodedata2       pkgs/main/linux-64::unicodedata2-15.1.0-py312h5eee18b_0
#
#
#
# Downloading and Extracting Packages:
# matplotlib-base-3.8. | 7.6 MB    |                                       |   0%
# fonttools-4.51.0     | 2.9 MB    |                                       |   0%
#
# pillow-10.4.0        | 946 KB    |                                       |   0%
#
#
# libtiff-4.5.1        | 533 KB    |                                       |   0%
#
#
#
# unicodedata2-15.1.0  | 519 KB    |                                       |   0%
#
#
#
#
# libwebp-base-1.3.2   | 387 KB    |                                       |   0%
#
#
#
#
#
# openjpeg-2.5.2       | 371 KB    |                                       |   0%
#
#
#
#
#
#
# lcms2-2.12           | 312 KB    |                                       |   0%
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 286 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 238 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 197 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 68 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 8 KB      |                                       |   0%
# matplotlib-base-3.8. | 7.6 MB    | #######################2              |  63%
#
#
#
#
# libwebp-base-1.3.2   | 387 KB    | #5                                    |   4%
#
#
#
#
#
# openjpeg-2.5.2       | 371 KB    | #5                                    |   4%
#
#
#
#
#
#
# lcms2-2.12           | 312 KB    | #9                                    |   5%
#
#
#
#
# libwebp-base-1.3.2   | 387 KB    | ##################################### | 100%
#
#
#
#
#
# openjpeg-2.5.2       | 371 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 286 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 238 KB    | ##4                                   |   7%
#
#
#
#
#
#
# lcms2-2.12           | 312 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 197 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 69 KB     | ########6                             |  23%
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 286 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 286 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 68 KB     | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 64 KB     | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 19 KB     | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 238 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 238 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 197 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 197 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lerc-3.0             | 196 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 68 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 68 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.17      | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 8 KB      | ##################################### | 100%
# fonttools-4.51.0     | 2.9 MB    | ##################################### | 100%
# matplotlib-base-3.8. | 7.6 MB    | ##################################### | 100%
#
#
# libtiff-4.5.1        | 533 KB    | #1                                    |   3%
#
#
# libtiff-4.5.1        | 533 KB    | ##################################### | 100%
#
#
# libtiff-4.5.1        | 533 KB    | ##################################### | 100%
#
# pillow-10.4.0        | 946 KB    | 6                                     |   2%
#
# pillow-10.4.0        | 946 KB    | ##################################### | 100%
#
# pillow-10.4.0        | 946 KB    | ##################################### | 100%
#
#
#
# unicodedata2-15.1.0  | 519 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt

# %%
# Create a list of the number of coin tosses ("Bernoulli trials")
number_of_trials = [0, 2, 10, 20, 50, 500]

# Conduct 500 coin tosses and output into a list of 0s and 1s
# where 0 represents a tail and 1 represents a head
data = stats.bernoulli.rvs(0.5, size=number_of_trials[-1])

# Discretise the x-axis into 100 separate plotting points
x = np.linspace(0, 1, 100)

# Loops over the number_of_trials list to continually add
# more coin toss data. For each new set of data, we update
# our (current) prior belief to be a new posterior. This is
# carried out using what is known as the Beta-Binomial model.
# For the time being, we won’t worry about this too much.
for i, N in enumerate(number_of_trials):
    # Accumulate the total number of heads for this
    # particular Bayesian update
    heads = data[:N].sum()

    # Create an axes subplot for each update
    ax = plt.subplot(len(number_of_trials) // 2, 2, i + 1)
    ax.set_title("%s trials, %s heads" % (N, heads))

    # Add labels to both axes and hide labels on y-axis
    plt.xlabel("$P(H)$, Probability of Heads")
    plt.ylabel("Density")
    if i == 0:
        plt.ylim([0.0, 2.0])
        plt.setp(ax.get_yticklabels(), visible=False)
    
    # Create and plot a Beta distribution to represent the
    # posterior belief in fairness of the coin.
    y = stats.beta.pdf(x, 1 + heads, 1 + N - heads)
    plt.plot(x, y, label="observe %d tosses,\n %d heads" % (N, heads))
    plt.fill_between(x, 0, y, color="#aaaadd", alpha=0.5)

# Expand plot to cover full width/height and show it
plt.tight_layout()
plt.show()
